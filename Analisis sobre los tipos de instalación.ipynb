# %%
import pandas as pd
import numpy as np

# plots
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
# %matplotlib inline
from wordcloud import WordCloud ## poner en consola 'python -m pip install wordcloud'

# %%
installs = pd.read_csv("Archivos/installs.csv",low_memory= False);

# %%
installs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3412 entries, 0 to 3411
# Data columns (total 18 columns):
# created               3412 non-null object
# application_id        3412 non-null int64
# ref_type              3412 non-null int64
# ref_hash              3412 non-null int64
# click_hash            0 non-null float64
# attributed            3412 non-null bool
# implicit              3412 non-null bool
# device_countrycode    3412 non-null int64
# device_brand          1047 non-null float64
# device_model          3411 non-null float64
# session_user_agent    3364 non-null object
# user_agent            1729 non-null object
# event_uuid            865 non-null object
# kind                  865 non-null object
# wifi                  1729 non-null object
# trans_id              6 non-null object
# ip_address            3412 non-null int64
# device_language       3378 non-null float64
# dtypes: bool(2), float64(4), int64(5), object(7)
# memory usage: 433.2+ KB

# %%
installs.columns
# Out:
# Index(['created', 'application_id', 'ref_type', 'ref_hash', 'click_hash',
#        'attributed', 'implicit', 'device_countrycode', 'device_brand',
#        'device_model', 'session_user_agent', 'user_agent', 'event_uuid',
#        'kind', 'wifi', 'trans_id', 'ip_address', 'device_language'],
#       dtype='object')

# %%
listaDeTerminosBuscados = installs['kind'].value_counts().reset_index()['index'].tolist()
listaDeTerminosBuscados
# Out:
# ['af_app_opened',
#  'app_open',
#  'EVENT_Homepage',
#  'open',
#  'EVENT_OPEN_APP',
#  'Open',
#  'login_success',
#  'account_summary_first_step',
#  'EVENT_HOMEPAGE',
#  'EVENT_LISTINGVIEW_FLIGHT',
#  'deeplink',
#  'reattribution',
#  'registration',
#  'payment method add',
#  'journey first drop off',
#  'journey drop off',
#  'install',
#  'journey reserved',
#  'EVENT_PROMO',
#  'af_list_view']

# %%
k = []
for i in listaDeTerminosBuscados:
    j = i.replace(' ','')
    j = j.lower()
    k.append(j)
    
listaDeTerminosBuscados = k
text = ' '.join(listaDeTerminosBuscados)

# %%
# Create the wordcloud object
wordcloud = WordCloud(width=1480, height=1480, background_color="green" ,margin=0,colormap="Reds", max_words=250).generate(text)
plt.figure(figsize=[14,19]) 
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

plt.show()

# %% [markdown]
# ##### Como se puede observar, las instalaciones realizadas en Jammps se centran en muchas ocurrencias que estan vinculadas con OPEN ( ya sea desde eventos para abrir la app) y LOGUEOS en la página.
