# %%
import numpy as np 
import pandas as pd

# plots
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
# %matplotlib inline

installs = pd.read_csv('../data/installs.csv',low_memory=False)

# %%
labelsx = installs['application_id'].value_counts().head(15).reset_index()['index'].unique().tolist()
labelsx
# Out:
# [7, 9, 10, 16, 8, 2, 29, 20, 6, 1, 26, 34, 15, 0, 3]

# %%
plot = installs['application_id'].value_counts().head(15).plot(kind='bar',figsize=(14,10),color = cm.Accent_r(np.linspace(.4,.8, 20)))
plot.set_xlabel('Id interno para la aplicación instalada',fontsize=16)
plot.set_ylabel('Cantidad de veces instalada una aplicación',fontsize=16)
plot.set_title('Top 15 de aplicaciones instalas en Jammp (aplicaciones más representativas)', fontsize=20)
plot.set_xticklabels(labels= labelsx, rotation=0)
plt.show()

# %% [markdown]
# Se puede observar en el gráfico que hay 2 aplicaciones que son las favoritas de los usuarios, las cuales tiene id '7' y '9' respectivamente. Luego las siguientes 3 están muy cerca entre ellas pero tienen la mitad de las instalaciones que las 2 primeras. Las aplicaciones ranqueadas en el quinto, sexto y séptimo lugar también compiten entre ellas de cerca. Pero a partir de la
